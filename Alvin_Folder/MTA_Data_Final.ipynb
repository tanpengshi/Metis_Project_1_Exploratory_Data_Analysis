# %% [markdown]
# # Metis Project 1 - MTA Exploratory Data Analysis
#
# ### Project Proposal:
#  An email from a potential client:
#
#  > Mike, Vinny & Julia -
#  >
#  > It was great to meet with you and chat at the event where we recently met and had a nice chat. We’d love to take some next steps to see if working together is something that would make sense for both parties.
#  >
#  > As we mentioned, we are interested in harnessing the power of data and analytics to optimize the effectiveness of our street team work, which is a significant portion of our fundraising efforts.
#  >
#  > WomenTechWomenYes (WTWY) has an annual gala at the beginning of the summer each year. As we are new and inclusive organization, we try to do double duty with the gala both to fill our event space with individuals passionate about increasing the participation of women in technology, and to concurrently build awareness and reach.
#  >
#  > To this end we place street teams at entrances to subway stations. The street teams collect email addresses and those who sign up are sent free tickets to our gala.
#  >
#  > Where we’d like to solicit your engagement is to use MTA subway data, which as I’m sure you know is available freely from the city, to help us optimize the placement of our street teams, such that we can gather the most signatures, ideally from those who will attend the gala and contribute to our cause.
#  >
#  > The ball is in your court now—do you think this is something that would be feasible for your group? From there we can explore what kind of an engagement would make sense for all of us.
#  >
#  > Best,
#  >
#  > Karrine and Dahlia
#  >
#  > WTWY International

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
pd.set_option('display.max_rows', 100)
# %matplotlib inline

# %%
#initialise the number of weeks for the dataset
num_weeks = 2

#initialise the date for the first week of the dataset (week ending on start_date)
startdate = filedate = pd.Timestamp('2020-08-22 00:00:00')

#initialise the regex for the MTA turnstile url
filename_regex = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

filelist = []

for numfiles in range (num_weeks):

    # create the appropriate filename for the week
    filedate_str = str(filedate.year)[-2:] + str(filedate.month).zfill(2) + str(filedate.day).zfill(2)
    filename = filename_regex.format(filedate_str)

    # read the file and append it to the list of files to be concatenated
    df = pd.read_csv(filename,parse_dates=['DATE'])
    filelist.append(df)

    # advance to the next week
    filedate += pd.Timedelta(days=7)

df = pd.concat(filelist, axis=0,ignore_index=True)

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT 2020-08-15
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT 2020-08-15
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT 2020-08-15
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT 2020-08-15
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT 2020-08-15
# ...       ...   ...       ...            ...      ...      ...        ...
# 427588  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2020-08-28
# 427589  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2020-08-28
# 427590  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2020-08-28
# 427591  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2020-08-28
# 427592  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT 2020-08-28
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  7444885
# 1       04:00:00  REGULAR  7444886
# 2       08:00:00  REGULAR  7444899
# 3       12:00:00  REGULAR  7444933
# 4       16:00:00  REGULAR  7445032
# ...          ...      ...      ...
# 427588  05:00:00  REGULAR     5554
# 427589  09:00:00  REGULAR     5554
# 427590  13:00:00  REGULAR     5554
# 427591  17:00:00  REGULAR     5554
# 427592  21:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2531033
# 1                                                 2531034
# 2                                                 2531046
# 3                                                 2531082
# 4                                                 2531110
# ...                                                   ...
# 427588                                                540
# 427589                                                540
# 427590                                                540
# 427591                                                540
# 427592                                                540
#
# [427593 rows x 11 columns]

# %%
df.groupby(['UNIT','SCP'])['STATION'].nunique().sort_values()  
#checking combination of 'UNIT' and 'SCP' is unique to each station,implying each combination refers to a unique turnstile
# Out:
# UNIT  SCP
# R001  00-00-00    1
# R273  00-00-01    1
#       00-00-00    1
# R272  01-06-02    1
#       01-06-01    1
#                  ..
# R112  01-06-01    1
#       01-06-00    1
#       01-05-01    1
# R113  00-00-04    1
# R572  01-03-04    1
# Name: STATION, Length: 4945, dtype: int64

# %%
df.sort_values(by=['DATE','TIME'])  #checking start/end of date/time
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00            59 ST  NQR456W      BMT 2020-08-15
# 42       A002  R051  02-00-01            59 ST  NQR456W      BMT 2020-08-15
# 84       A002  R051  02-03-00            59 ST  NQR456W      BMT 2020-08-15
# 126      A002  R051  02-03-01            59 ST  NQR456W      BMT 2020-08-15
# 168      A002  R051  02-03-02            59 ST  NQR456W      BMT 2020-08-15
# ...       ...   ...       ...              ...      ...      ...        ...
# 339113  PTH05  R543  00-01-03   EXCHANGE PLACE        1      PTH 2020-08-28
# 343843  PTH17  R541  01-00-08  THIRTY THIRD ST        1      PTH 2020-08-28
# 336171  PTH02  R544  00-03-02         HARRISON        1      PTH 2020-08-28
# 344804  PTH18  R549  01-02-01     NEWARK BM BW        1      PTH 2020-08-28
# 345644  PTH19  R549  02-02-04         NEWARK C        1      PTH 2020-08-28
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  7444885
# 42      00:00:00  REGULAR  6612017
# 84      00:00:00  REGULAR  1384921
# 126     00:00:00  REGULAR  1471517
# 168     00:00:00  REGULAR  6564529
# ...          ...      ...      ...
# 339113  23:59:14  REGULAR   193584
# 343843  23:59:22  REGULAR   508223
# 336171  23:59:24  REGULAR     4477
# 344804  23:59:26  REGULAR   116978
# 345644  23:59:47  REGULAR    16598
#
#         EXITS
# 0                                                 2531033
# 42                                                1491877
# 84                                                5218302
# 126                                               2287301
# 168                                               8762691
# ...                                                   ...
# 339113                                             235949
# 343843                                             381208
# 336171                                               1058
# 344804                                               6571
# 345644                                               2949
#
# [427593 rows x 11 columns]

# %%
df['TIME']=pd.to_datetime(df['TIME'],format='%H:%M:%S').dt.time

# %%
df = df.sort_values(by=['UNIT','SCP','DATE','TIME'])
df.head(100)    
# arranging proper order of data by 'UNIT','SCP','DATE','TIME'.
# each 'UNIT' can have multiple 'SCP'
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 10969   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10970   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10971   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10972   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10973   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10974   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10975   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10976   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10977   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10978   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10979   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10980   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 10981   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10982   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10983   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10984   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10985   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10986   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 10987   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10988   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10989   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10990   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10991   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10992   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-18
# 10993   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10994   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10995   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10996   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10997   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10998   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-19
# 10999   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11000   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11001   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11002   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11003   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11004   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-20
# 11005   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 11006   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 11007   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 11008   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 11009   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 11010   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-21
# 220714  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220715  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220716  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220717  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220718  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220719  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220720  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220721  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220722  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220723  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220724  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220725  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-23
# 220726  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220727  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220728  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220729  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220730  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220731  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-24
# 220732  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220733  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220734  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220735  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220736  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220737  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-25
# 220738  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220739  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220740  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220741  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220742  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220743  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-26
# 220744  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220745  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220746  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220747  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220748  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220749  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-27
# 220750  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 220751  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 220752  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 220753  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 220754  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 220755  A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-28
# 11011   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11012   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11013   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11014   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11015   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11016   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 11017   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11018   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11019   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11020   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11021   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11022   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-16
# 11023   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 11024   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 11025   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-17
# 11026   A060  R001  00-00-01  WHITEHALL S-FRY      R1W      BMT 2020-08-17
#
#             TIME     DESC  ENTRIES  \
# 10969   01:00:00  REGULAR  5106326
# 10970   05:00:00  REGULAR  5106329
# 10971   09:00:00  REGULAR  5106475
# 10972   13:00:00  REGULAR  5106602
# 10973   17:00:00  REGULAR  5106819
# 10974   21:00:00  REGULAR  5107030
# 10975   01:00:00  REGULAR  5107108
# 10976   05:00:00  REGULAR  5107110
# 10977   09:00:00  REGULAR  5107197
# 10978   13:00:00  REGULAR  5107284
# 10979   17:00:00  REGULAR  5107411
# 10980   21:00:00  REGULAR  5107551
# 10981   01:00:00  REGULAR  5107613
# 10982   05:00:00  REGULAR  5107614
# 10983   09:00:00  REGULAR  5107918
# 10984   13:00:00  REGULAR  5108094
# 10985   17:00:00  REGULAR  5108267
# 10986   21:00:00  REGULAR  5108412
# 10987   01:00:00  REGULAR  5108461
# 10988   05:00:00  REGULAR  5108464
# 10989   09:00:00  REGULAR  5108764
# 10990   13:00:00  REGULAR  5108937
# 10991   17:00:00  REGULAR  5109102
# 10992   21:00:00  REGULAR  5109255
# 10993   01:00:00  REGULAR  5109339
# 10994   05:00:00  REGULAR  5109340
# 10995   09:00:00  REGULAR  5109628
# 10996   13:00:00  REGULAR  5109795
# 10997   17:00:00  REGULAR  5109953
# 10998   21:00:00  REGULAR  5110096
# 10999   01:00:00  REGULAR  5110158
# 11000   05:00:00  REGULAR  5110158
# 11001   09:00:00  REGULAR  5110446
# 11002   13:00:00  REGULAR  5110631
# 11003   17:00:00  REGULAR  5110812
# 11004   21:00:00  REGULAR  5110978
# 11005   01:00:00  REGULAR  5111051
# 11006   05:00:00  REGULAR  5111051
# 11007   09:00:00  REGULAR  5111323
# 11008   13:00:00  REGULAR  5111513
# 11009   17:00:00  REGULAR  5111705
# 11010   21:00:00  REGULAR  5111928
# 220714  01:00:00  REGULAR  5112012
# 220715  05:00:00  REGULAR  5112014
# 220716  09:00:00  REGULAR  5112140
# 220717  13:00:00  REGULAR  5112299
# 220718  17:00:00  REGULAR  5112514
# 220719  21:00:00  REGULAR  5112740
# 220720  01:00:00  REGULAR  5112832
# 220721  05:00:00  REGULAR  5112832
# 220722  09:00:00  REGULAR  5112922
# 220723  13:00:00  REGULAR  5113041
# 220724  17:00:00  REGULAR  5113227
# 220725  21:00:00  REGULAR  5113421
# 220726  01:00:00  REGULAR  5113495
# 220727  05:00:00  REGULAR  5113495
# 220728  09:00:00  REGULAR  5113764
# 220729  13:00:00  REGULAR  5113946
# 220730  17:00:00  REGULAR  5114115
# 220731  21:00:00  REGULAR  5114292
# 220732  01:00:00  REGULAR  5114351
# 220733  05:00:00  REGULAR  5114351
# 220734  09:00:00  REGULAR  5114550
# 220735  13:00:00  REGULAR  5114697
# 220736  17:00:00  REGULAR  5114852
# 220737  21:00:00  REGULAR  5115011
# 220738  01:00:00  REGULAR  5115077
# 220739  05:00:00  REGULAR  5115078
# 220740  09:00:00  REGULAR  5115369
# 220741  13:00:00  REGULAR  5115576
# 220742  17:00:00  REGULAR  5115767
# 220743  21:00:00  REGULAR  5115963
# 220744  01:00:00  REGULAR  5116044
# 220745  05:00:00  REGULAR  5116046
# 220746  09:00:00  REGULAR  5116355
# 220747  13:00:00  REGULAR  5116552
# 220748  17:00:00  REGULAR  5116769
# 220749  21:00:00  REGULAR  5116922
# 220750  01:00:00  REGULAR  5116991
# 220751  05:00:00  REGULAR  5116996
# 220752  09:00:00  REGULAR  5117286
# 220753  13:00:00  REGULAR  5117506
# 220754  17:00:00  REGULAR  5117714
# 220755  21:00:00  REGULAR  5117874
# 11011   01:00:00  REGULAR  4034295
# 11012   05:00:00  REGULAR  4034295
# 11013   09:00:00  REGULAR  4034350
# 11014   13:00:00  REGULAR  4034416
# 11015   17:00:00  REGULAR  4034539
# 11016   21:00:00  REGULAR  4034649
# 11017   01:00:00  REGULAR  4034682
# 11018   05:00:00  REGULAR  4034683
# 11019   09:00:00  REGULAR  4034724
# 11020   13:00:00  REGULAR  4034773
# 11021   17:00:00  REGULAR  4034840
# 11022   21:00:00  REGULAR  4034898
# 11023   01:00:00  REGULAR  4034926
# 11024   05:00:00  REGULAR  4034926
# 11025   09:00:00  REGULAR  4035098
# 11026   13:00:00  REGULAR  4035188
#
#         EXITS
# 10969                                             2946514
# 10970                                             2946516
# 10971                                             2946572
# 10972                                             2946704
# 10973                                             2946900
# 10974                                             2946978
# 10975                                             2947016
# 10976                                             2947020
# 10977                                             2947057
# 10978                                             2947097
# 10979                                             2947173
# 10980                                             2947223
# 10981                                             2947259
# 10982                                             2947267
# 10983                                             2947318
# 10984                                             2947374
# 10985                                             2947494
# 10986                                             2947592
# 10987                                             2947637
# 10988                                             2947637
# 10989                                             2947686
# 10990                                             2947738
# 10991                                             2947892
# 10992                                             2947999
# 10993                                             2948045
# 10994                                             2948053
# 10995                                             2948110
# 10996                                             2948150
# 10997                                             2948278
# 10998                                             2948392
# 10999                                             2948440
# 11000                                             2948444
# 11001                                             2948490
# 11002                                             2948550
# 11003                                             2948670
# 11004                                             2948775
# 11005                                             2948817
# 11006                                             2948825
# 11007                                             2948869
# 11008                                             2948922
# 11009                                             2949045
# 11010                                             2949136
# 220714                                            2949184
# 220715                                            2949186
# 220716                                            2949228
# 220717                                            2949286
# 220718                                            2949380
# 220719                                            2949458
# 220720                                            2949517
# 220721                                            2949518
# 220722                                            2949549
# 220723                                            2949603
# 220724                                            2949676
# 220725                                            2949729
# 220726                                            2949764
# 220727                                            2949766
# 220728                                            2949809
# 220729                                            2949866
# 220730                                            2949972
# 220731                                            2950098
# 220732                                            2950126
# 220733                                            2950139
# 220734                                            2950192
# 220735                                            2950236
# 220736                                            2950368
# 220737                                            2950471
# 220738                                            2950502
# 220739                                            2950505
# 220740                                            2950563
# 220741                                            2950606
# 220742                                            2950722
# 220743                                            2950829
# 220744                                            2950869
# 220745                                            2950877
# 220746                                            2950924
# 220747                                            2950982
# 220748                                            2951111
# 220749                                            2951219
# 220750                                            2951267
# 220751                                            2951276
# 220752                                            2951341
# 220753                                            2951394
# 220754                                            2951538
# 220755                                            2951665
# 11011                                             2544527
# 11012                                             2544528
# 11013                                             2544566
# 11014                                             2544692
# 11015                                             2544892
# 11016                                             2544968
# 11017                                             2545012
# 11018                                             2545015
# 11019                                             2545040
# 11020                                             2545065
# 11021                                             2545119
# 11022                                             2545161
# 11023                                             2545192
# 11024                                             2545196
# 11025                                             2545235
# 11026                                             2545270

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns = [column.strip() for column in df.columns]
# strip column names of blank spaces

# %%
df['ENTRY_DELTA'] = df['ENTRIES'].diff()
df['EXIT_DELTA'] = df['EXITS'].diff()
# Finding the difference in values between consecutive rows to find out traffic flow between timings

# %%
df
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 10969    A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10970    A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10971    A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10972    A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# 10973    A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-15
# ...       ...   ...       ...              ...      ...      ...        ...
# 334837  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334838  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334839  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334840  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334841  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
#
#             TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  EXIT_DELTA
# 10969   01:00:00  REGULAR  5106326  2946514          NaN         NaN
# 10970   05:00:00  REGULAR  5106329  2946516          3.0         2.0
# 10971   09:00:00  REGULAR  5106475  2946572        146.0        56.0
# 10972   13:00:00  REGULAR  5106602  2946704        127.0       132.0
# 10973   17:00:00  REGULAR  5106819  2946900        217.0       196.0
# ...          ...      ...      ...      ...          ...         ...
# 334837  05:00:00  REGULAR  1503374   494247          0.0         6.0
# 334838  09:00:00  REGULAR  1503446   494287         72.0        40.0
# 334839  13:00:00  REGULAR  1503514   494314         68.0        27.0
# 334840  17:00:00  REGULAR  1503623   494341        109.0        27.0
# 334841  21:00:00  REGULAR  1503701   494373         78.0        32.0
#
# [427593 rows x 13 columns]

# %%
df = df[df['DATE']>=pd.Timestamp('2020-08-22 00:00:00')]
df
# Taking the week of 22/8 to 28/8
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 220714   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220715   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220716   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220717   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 220718   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# ...       ...   ...       ...              ...      ...      ...        ...
# 334837  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334838  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334839  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334840  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 334841  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
#
#             TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  EXIT_DELTA
# 220714  01:00:00  REGULAR  5112012  2949184         84.0        48.0
# 220715  05:00:00  REGULAR  5112014  2949186          2.0         2.0
# 220716  09:00:00  REGULAR  5112140  2949228        126.0        42.0
# 220717  13:00:00  REGULAR  5112299  2949286        159.0        58.0
# 220718  17:00:00  REGULAR  5112514  2949380        215.0        94.0
# ...          ...      ...      ...      ...          ...         ...
# 334837  05:00:00  REGULAR  1503374   494247          0.0         6.0
# 334838  09:00:00  REGULAR  1503446   494287         72.0        40.0
# 334839  13:00:00  REGULAR  1503514   494314         68.0        27.0
# 334840  17:00:00  REGULAR  1503623   494341        109.0        27.0
# 334841  21:00:00  REGULAR  1503701   494373         78.0        32.0
#
# [217832 rows x 13 columns]

# %%
df['ENTRY_DELTA'][df['ENTRY_DELTA']<0]
# Checking reset of entry counter values
# Out:
# 252044   -8291685.0
# 264128        -91.0
# 264129         -4.0
# 264130        -34.0
# 264131        -25.0
#             ...
# 341647     -17768.0
# 339394    -210087.0
# 342664     -80186.0
# 337985     -32882.0
# 337631      -1508.0
# Name: ENTRY_DELTA, Length: 1724, dtype: float64

# %%
df['ENTRY_DELTA'][df['ENTRY_DELTA']>10000]
# Checking reset of entry counter values
# Out:
# 271427    1.057536e+09
# 271465    1.549702e+09
# 300430    8.368614e+07
# 297544    1.443527e+06
# 297546    1.443555e+06
# 241440    6.512100e+04
# 241509    3.245470e+05
# 241515    1.966110e+05
# 296920    1.405439e+06
# Name: ENTRY_DELTA, dtype: float64

# %%
df['EXIT_DELTA'][df['EXIT_DELTA']<0]
# Checking reset of exit counter values
# Out:
# 252044   -5618417.0
# 372575         -1.0
# 372585         -2.0
# 371439      -2794.0
# 378552         -1.0
#             ...
# 341647      -2261.0
# 339394     -27583.0
# 342664    -101904.0
# 337985    -266037.0
# 337631      -1199.0
# Name: EXIT_DELTA, Length: 1345, dtype: float64

# %%
df['EXIT_DELTA'][df['EXIT_DELTA']>10000]
# Checking reset of exit counter values
# Out:
# 300430      82744.0
# 297544    2955446.0
# 297546    2955411.0
# 241509      53279.0
# 296920     228341.0
# Name: EXIT_DELTA, dtype: float64

# %%
df['ENTRY_DELTA'][df['ENTRY_DELTA']>10000]=np.nan
df['ENTRY_DELTA'][df['ENTRY_DELTA']<0]=np.nan
df['EXIT_DELTA'][df['EXIT_DELTA']>10000]=np.nan
df['EXIT_DELTA'][df['EXIT_DELTA']<0]=np.nan
# Setting the anomaly values due to reset of counters to the uniform NaN values
# Out:
# <ipython-input-17-6417b5b41e57>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ENTRY_DELTA'][df['ENTRY_DELTA']>10000]=np.nan
# C:\Users\tanpe\Anaconda3\lib\site-packages\pandas\core\generic.py:8765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# <ipython-input-17-6417b5b41e57>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ENTRY_DELTA'][df['ENTRY_DELTA']<0]=np.nan
# <ipython-input-17-6417b5b41e57>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXIT_DELTA'][df['EXIT_DELTA']>10000]=np.nan
# <ipython-input-17-6417b5b41e57>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXIT_DELTA'][df['EXIT_DELTA']<0]=np.nan

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
# C:\Users\tanpe\Anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 0        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 1        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 2        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 3        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 4        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# ...       ...   ...       ...              ...      ...      ...        ...
# 217827  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217828  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217829  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217830  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217831  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
#
#             TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  EXIT_DELTA
# 0       01:00:00  REGULAR  5112012  2949184         84.0        48.0
# 1       05:00:00  REGULAR  5112014  2949186          2.0         2.0
# 2       09:00:00  REGULAR  5112140  2949228        126.0        42.0
# 3       13:00:00  REGULAR  5112299  2949286        159.0        58.0
# 4       17:00:00  REGULAR  5112514  2949380        215.0        94.0
# ...          ...      ...      ...      ...          ...         ...
# 217827  05:00:00  REGULAR  1503374   494247          0.0         6.0
# 217828  09:00:00  REGULAR  1503446   494287         72.0        40.0
# 217829  13:00:00  REGULAR  1503514   494314         68.0        27.0
# 217830  17:00:00  REGULAR  1503623   494341        109.0        27.0
# 217831  21:00:00  REGULAR  1503701   494373         78.0        32.0
#
# [217832 rows x 13 columns]

# %%
delta_list = list(df['ENTRY_DELTA'])
ind = 0
for i in delta_list:
    if np.isnan(i) == 1:
        delta_list[ind] = np.nanmean([delta_list[ind-2],delta_list[ind-1],delta_list[ind+1],delta_list[ind+2]])
    ind += 1
    
df['ENTRY_DELTA_1'] = delta_list 
# for each NaN values, replace it with the mean of values before and after the NaN value
# Out:
# <ipython-input-20-ca1d63dde3e9>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ENTRY_DELTA_1'] = delta_list

# %%
df['ENTRY_DELTA_1'].isnull().sum()
# check for any NaN values remaining
# Out:
# 0

# %%
delta_list = list(df['EXIT_DELTA'])
ind = 0
for i in delta_list:
    if np.isnan(i) == 1:
        delta_list[ind] = np.nanmean([delta_list[ind-1],delta_list[ind+1]])
    ind += 1
    
df['EXIT_DELTA_1'] = delta_list 
# for each NaN values, replace it with the mean of values before and after the NaN value
# Out:
# <ipython-input-22-aaf8f870e747>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXIT_DELTA_1'] = delta_list

# %%
df['EXIT_DELTA_1'].isnull().sum()
# check for any NaN values remaining
# Out:
# 0

# %%
df['ENTRY_EXIT'] = df['ENTRY_DELTA_1'] + df['EXIT_DELTA_1']
df
# find out the total traffic from entry and exit between each timing
# Out:
# <ipython-input-24-355451511537>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ENTRY_EXIT'] = df['ENTRY_DELTA_1'] + df['EXIT_DELTA_1']
#           C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 0        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 1        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 2        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 3        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# 4        A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2020-08-22
# ...       ...   ...       ...              ...      ...      ...        ...
# 217827  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217828  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217829  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217830  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
# 217831  N702A  R572  01-03-04      96 ST-2 AVE        Q      IND 2020-08-28
#
#             TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  EXIT_DELTA  \
# 0       01:00:00  REGULAR  5112012  2949184         84.0        48.0
# 1       05:00:00  REGULAR  5112014  2949186          2.0         2.0
# 2       09:00:00  REGULAR  5112140  2949228        126.0        42.0
# 3       13:00:00  REGULAR  5112299  2949286        159.0        58.0
# 4       17:00:00  REGULAR  5112514  2949380        215.0        94.0
# ...          ...      ...      ...      ...          ...         ...
# 217827  05:00:00  REGULAR  1503374   494247          0.0         6.0
# 217828  09:00:00  REGULAR  1503446   494287         72.0        40.0
# 217829  13:00:00  REGULAR  1503514   494314         68.0        27.0
# 217830  17:00:00  REGULAR  1503623   494341        109.0        27.0
# 217831  21:00:00  REGULAR  1503701   494373         78.0        32.0
#
#         ENTRY_DELTA_1  EXIT_DELTA_1  ENTRY_EXIT
# 0                84.0          48.0       132.0
# 1                 2.0           2.0         4.0
# 2               126.0          42.0       168.0
# 3               159.0          58.0       217.0
# 4               215.0          94.0       309.0
# ...               ...           ...         ...
# 217827            0.0           6.0         6.0
# 217828           72.0          40.0       112.0
# 217829           68.0          27.0        95.0
# 217830          109.0          27.0       136.0
# 217831           78.0          32.0       110.0
#
# [217832 rows x 16 columns]

# %%
group_station = df.groupby('STATION')['ENTRY_EXIT'].sum().sort_values(ascending=False)
group_station.head(10)
# Checking the top 10 station for traffic in the week 22/8/20 to 28/8/20
# Out:
# STATION
# 34 ST-PENN STA     401500.083333
# 34 ST-HERALD SQ    349965.194444
# 125 ST             296509.612952
# 42 ST-PORT AUTH    285518.681520
# 86 ST              273233.500000
# GRD CNTRL-42 ST    267895.076389
# 14 ST-UNION SQ     262992.000000
# 23 ST              237353.749718
# FLUSHING-MAIN      219646.000000
# FULTON ST          213414.000000
# Name: ENTRY_EXIT, dtype: float64

# %%
plt.figure(figsize=[8,5])
ax = sns.barplot(data=group_station.head(10).reset_index(),x='ENTRY_EXIT',y='STATION',palette='rainbow')
plt.xlabel('Total Traffic',weight='bold',fontsize=15)
plt.ylabel('Top 10 Stations',weight='bold',fontsize=15)
plt.xticks(range(0,400001,50000),[str(int(i/1000))+'k' for i in range(0,400001,50000)])
plt.title('Busiest MTA Stations from 22/8 to 28/8', weight='bold',fontsize='15')
for p in ax.patches:
        ax.annotate(str(int(p.get_width()/1000))+'k', (p.get_width(), p.get_y()+0.5))
sns.despine()
plt.savefig('barplot.png',transparent=True, bbox_inches='tight')

# Creating a horizontal bar plot of top 10 stations traffic from week 22/8/20 to 28/8/20

# %%
len(group_station)
# Out:
# 379

# %%
fig1 = plt.figure(figsize=[8,6])
ax1 = sns.distplot(group_station,bins=50,kde=False)
plt.xlim([0,410000])
plt.ylabel('No. of Stations',fontsize=15, weight='bold')
plt.xlabel('Total Traffic', fontsize=15, weight='bold')
ax1.annotate('Top 10 Stations', xy=(0.73, 0.08), xytext=(0.73, 0.12), xycoords='axes fraction', 
            fontsize=12, ha='center', va='bottom',
            arrowprops=dict(arrowstyle='-[, widthB=9.0, lengthB=1', lw=1.0),color='blue')
plt.title('Distribution of Traffic Across Stations',fontsize=15,weight='bold')
sns.despine()

plt.savefig('histplot.png',transparent=True, bbox_inches='tight')

# Checking Distribution of traffic in all stations, showing a right-skewed distribution
# Top 10 Stations represent an anomaly, and therefore should be the focus for the street teams given limited manpower resources

# %%
df['WEEKDAY'] = df['DATE'].dt.day_name()
group = df.groupby(['STATION','WEEKDAY'])['ENTRY_EXIT'].sum()
group = group.reset_index()
group.sort_values(by='ENTRY_EXIT').head(100)

# Finding all traffic a day in all stations
# Out:
# <ipython-input-29-2a89213e20fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WEEKDAY'] = df['DATE'].dt.day_name()
#               STATION    WEEKDAY  ENTRY_EXIT
# 2166    ORCHARD BEACH     Sunday         0.0
# 2169    ORCHARD BEACH  Wednesday         0.0
# 2163    ORCHARD BEACH     Friday         0.0
# 2165    ORCHARD BEACH   Saturday         0.0
# 2167    ORCHARD BEACH   Thursday         0.0
# 2164    ORCHARD BEACH     Monday         1.0
# 2168    ORCHARD BEACH    Tuesday         1.0
# 927          AVENUE P     Sunday        10.0
# 2047       NEPTUNE AV     Sunday        10.0
# 1410        DITMAS AV     Sunday        12.0
# 899          AVENUE I     Sunday        21.0
# 850   AQUEDUCT RACETR     Sunday        25.0
# 402             33 ST     Sunday        25.0
# 920          AVENUE N     Sunday        28.0
# 941          AVENUE X     Sunday        33.0
# 898          AVENUE I   Saturday        35.0
# 849   AQUEDUCT RACETR   Saturday        40.0
# 919          AVENUE N   Saturday        43.0
# 2046       NEPTUNE AV   Saturday        45.0
# 857          ASTOR PL     Sunday        50.0
# 853   AQUEDUCT RACETR  Wednesday        61.0
# 851   AQUEDUCT RACETR   Thursday        63.0
# 852   AQUEDUCT RACETR    Tuesday        64.0
# 848   AQUEDUCT RACETR     Monday        64.0
# 847   AQUEDUCT RACETR     Friday        65.0
# 926          AVENUE P   Saturday        72.0
# 2481    TOMPKINSVILLE     Sunday        74.0
# 1116    BOWLING GREEN     Sunday        77.0
# 1409        DITMAS AV   Saturday        77.0
# 1137    BROAD CHANNEL     Sunday        81.0
# 940          AVENUE X   Saturday       100.0
# 2480    TOMPKINSVILLE   Saturday       112.0
# 1136    BROAD CHANNEL   Saturday       113.0
# 1134    BROAD CHANNEL     Friday       146.0
# 1139    BROAD CHANNEL    Tuesday       154.0
# 1140    BROAD CHANNEL  Wednesday       160.0
# 1135    BROAD CHANNEL     Monday       164.0
# 1138    BROAD CHANNEL   Thursday       172.0
# 2484    TOMPKINSVILLE  Wednesday       185.0
# 2483    TOMPKINSVILLE    Tuesday       200.0
# 2482    TOMPKINSVILLE   Thursday       207.0
# 2479    TOMPKINSVILLE     Monday       208.0
# 2478    TOMPKINSVILLE     Friday       217.0
# 843   AQUEDUCT N.COND     Sunday       224.0
# 991      BEACH 105 ST   Thursday       243.0
# 401             33 ST   Saturday       247.0
# 842   AQUEDUCT N.COND   Saturday       257.0
# 856          ASTOR PL   Saturday       276.0
# 988      BEACH 105 ST     Monday       354.0
# 990      BEACH 105 ST     Sunday       401.0
# 1040      BEACH 98 ST   Thursday       404.0
# 1991      MORRIS PARK     Sunday       405.0
# 2095         NEWARK C   Saturday       428.0
# 1424  E 143/ST MARY'S     Sunday       441.0
# 885       ATLANTIC AV     Sunday       447.0
# 304            215 ST     Sunday       451.0
# 1037      BEACH 98 ST     Monday       460.0
# 992      BEACH 105 ST    Tuesday       471.0
# 1179  BROOKLYN BRIDGE     Sunday       482.0
# 993      BEACH 105 ST  Wednesday       499.0
# 1011      BEACH 44 ST     Sunday       503.0
# 1042      BEACH 98 ST  Wednesday       504.0
# 1039      BEACH 98 ST     Sunday       515.0
# 703             75 AV     Sunday       519.0
# 1389    CYPRESS HILLS     Sunday       525.0
# 576             55 ST   Saturday       528.0
# 1036      BEACH 98 ST     Friday       550.0
# 1423  E 143/ST MARY'S   Saturday       554.0
# 1041      BEACH 98 ST    Tuesday       554.0
# 1557      FRANKLIN ST     Sunday       558.0
# 840   AQUEDUCT N.COND     Friday       562.0
# 2411       ST. GEORGE     Sunday       592.0
# 987      BEACH 105 ST     Friday       595.0
# 1990      MORRIS PARK   Saturday       597.0
# 1725    HUNTERS PT AV     Sunday       599.0
# 845   AQUEDUCT N.COND    Tuesday       602.0
# 1115    BOWLING GREEN   Saturday       607.0
# 1963    MIDDLETOWN RD     Sunday       613.0
# 955         BAY 50 ST     Sunday       616.0
# 983     BAYCHESTER AV     Sunday       616.0
# 884       ATLANTIC AV   Saturday       621.0
# 787             88 ST     Sunday       624.0
# 841   AQUEDUCT N.COND     Monday       647.0
# 844   AQUEDUCT N.COND   Thursday       649.0
# 1102   BOTANIC GARDEN     Sunday       650.0
# 846   AQUEDUCT N.COND  Wednesday       653.0
# 1361   COURT SQ-23 ST     Sunday       656.0
# 954         BAY 50 ST   Saturday       680.0
# 1165  BRONX PARK EAST     Sunday       683.0
# 1388    CYPRESS HILLS   Saturday       687.0
# 1010      BEACH 44 ST   Saturday       690.0
# 2045       NEPTUNE AV     Monday       704.0
# 302            215 ST     Monday       709.0
# 59             121 ST     Sunday       710.0
# 1009      BEACH 44 ST     Monday       711.0
# 2096         NEWARK C     Sunday       716.0
# 1004      BEACH 36 ST     Sunday       719.0
# 451             39 AV     Sunday       733.0
# 1556      FRANKLIN ST   Saturday       738.0
# 2044       NEPTUNE AV     Friday       739.0

# %%
group = group[group['STATION']!='ORCHARD BEACH']
# Orchard Beach station might be non-operational

# %%
sns.boxplot(x='WEEKDAY',y='ENTRY_EXIT',data=group,order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])

# boxplot of all week days confirmed the right skewed distribution with several extreme outliers

# %%
df_10 = df[df['STATION'].isin(list(group_station.head(10).index))]
df_10
# filter out dataframe for the top 10 stations for further data visualization
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2925    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2926    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2927    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2928    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2929    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# ...       ...   ...       ...              ...           ...      ...
# 197616   N508  R453  00-00-05            23 ST            FM      IND
# 197617   N508  R453  00-00-05            23 ST            FM      IND
# 197618   N508  R453  00-00-05            23 ST            FM      IND
# 197619   N508  R453  00-00-05            23 ST            FM      IND
# 197620   N508  R453  00-00-05            23 ST            FM      IND
#
#              DATE      TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  \
# 2925   2020-08-22  02:00:00  REGULAR  9247170  2202347        138.0
# 2926   2020-08-22  06:00:00  REGULAR  9247192  2202357         22.0
# 2927   2020-08-22  10:00:00  REGULAR  9247304  2202437        112.0
# 2928   2020-08-22  14:00:00  REGULAR  9247494  2202541        190.0
# 2929   2020-08-22  18:00:00  REGULAR  9247726  2202659        232.0
# ...           ...       ...      ...      ...      ...          ...
# 197616 2020-08-28  04:00:00  REGULAR   694272  1777400          4.0
# 197617 2020-08-28  08:00:00  REGULAR   694276  1777613          4.0
# 197618 2020-08-28  12:00:00  REGULAR   694303  1777995         27.0
# 197619 2020-08-28  16:00:00  REGULAR   694400  1778301         97.0
# 197620 2020-08-28  20:00:00  REGULAR   694518  1778564        118.0
#
#         EXIT_DELTA  ENTRY_DELTA_1  EXIT_DELTA_1  ENTRY_EXIT   WEEKDAY
# 2925          99.0          138.0          99.0       237.0  Saturday
# 2926          10.0           22.0          10.0        32.0  Saturday
# 2927          80.0          112.0          80.0       192.0  Saturday
# 2928         104.0          190.0         104.0       294.0  Saturday
# 2929         118.0          232.0         118.0       350.0  Saturday
# ...            ...            ...           ...         ...       ...
# 197616         1.0            4.0           1.0         5.0    Friday
# 197617       213.0            4.0         213.0       217.0    Friday
# 197618       382.0           27.0         382.0       409.0    Friday
# 197619       306.0           97.0         306.0       403.0    Friday
# 197620       263.0          118.0         263.0       381.0    Friday
#
# [26221 rows x 17 columns]

# %%
df_10['WEEKDAY'] = df_10['DATE'].dt.day_name()
df_10
# Out:
# <ipython-input-33-d2de689e979e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10['WEEKDAY'] = df_10['DATE'].dt.day_name()
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2925    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2926    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2927    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2928    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2929    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# ...       ...   ...       ...              ...           ...      ...
# 197616   N508  R453  00-00-05            23 ST            FM      IND
# 197617   N508  R453  00-00-05            23 ST            FM      IND
# 197618   N508  R453  00-00-05            23 ST            FM      IND
# 197619   N508  R453  00-00-05            23 ST            FM      IND
# 197620   N508  R453  00-00-05            23 ST            FM      IND
#
#              DATE      TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  \
# 2925   2020-08-22  02:00:00  REGULAR  9247170  2202347        138.0
# 2926   2020-08-22  06:00:00  REGULAR  9247192  2202357         22.0
# 2927   2020-08-22  10:00:00  REGULAR  9247304  2202437        112.0
# 2928   2020-08-22  14:00:00  REGULAR  9247494  2202541        190.0
# 2929   2020-08-22  18:00:00  REGULAR  9247726  2202659        232.0
# ...           ...       ...      ...      ...      ...          ...
# 197616 2020-08-28  04:00:00  REGULAR   694272  1777400          4.0
# 197617 2020-08-28  08:00:00  REGULAR   694276  1777613          4.0
# 197618 2020-08-28  12:00:00  REGULAR   694303  1777995         27.0
# 197619 2020-08-28  16:00:00  REGULAR   694400  1778301         97.0
# 197620 2020-08-28  20:00:00  REGULAR   694518  1778564        118.0
#
#         EXIT_DELTA  ENTRY_DELTA_1  EXIT_DELTA_1  ENTRY_EXIT   WEEKDAY
# 2925          99.0          138.0          99.0       237.0  Saturday
# 2926          10.0           22.0          10.0        32.0  Saturday
# 2927          80.0          112.0          80.0       192.0  Saturday
# 2928         104.0          190.0         104.0       294.0  Saturday
# 2929         118.0          232.0         118.0       350.0  Saturday
# ...            ...            ...           ...         ...       ...
# 197616         1.0            4.0           1.0         5.0    Friday
# 197617       213.0            4.0         213.0       217.0    Friday
# 197618       382.0           27.0         382.0       409.0    Friday
# 197619       306.0           97.0         306.0       403.0    Friday
# 197620       263.0          118.0         263.0       381.0    Friday
#
# [26221 rows x 17 columns]

# %%
group_station_day = df_10.groupby(['STATION','WEEKDAY'])['ENTRY_EXIT'].sum()
group_station_day

# Finding all traffic a day in the top 10 stations
# Out:
# STATION          WEEKDAY
# 125 ST           Friday       48069.541287
#                  Monday       44418.669718
#                  Saturday     35352.666667
#                  Sunday       28188.611979
#                  Thursday     46910.372591
#                  Tuesday      46464.529996
#                  Wednesday    47105.220714
# 14 ST-UNION SQ   Friday       44337.000000
#                  Monday       39818.000000
#                  Saturday     30561.000000
#                  Sunday       21390.000000
#                  Thursday     41454.000000
#                  Tuesday      40898.000000
#                  Wednesday    44534.000000
# 23 ST            Friday       39505.750115
#                  Monday       37074.998372
#                  Saturday     23391.437500
#                  Sunday       17730.897461
#                  Thursday     40385.011147
#                  Tuesday      38743.937417
#                  Wednesday    40521.717705
# 34 ST-HERALD SQ  Friday       55324.638889
#                  Monday       54277.995567
#                  Saturday     39598.843750
#                  Sunday       31155.716309
#                  Thursday     55887.000000
#                  Tuesday      56004.999931
#                  Wednesday    57715.999999
# 34 ST-PENN STA   Friday       65294.416667
#                  Monday       63903.001602
#                  Saturday     42422.562500
#                  Sunday       33385.102539
#                  Thursday     65944.000000
#                  Tuesday      64304.000025
#                  Wednesday    66247.000000
# 42 ST-PORT AUTH  Friday       46356.164545
#                  Monday       44105.076804
#                  Saturday     33792.341146
#                  Sunday       24899.040487
#                  Thursday     45814.013893
#                  Tuesday      44474.030497
#                  Wednesday    46078.014148
# 86 ST            Friday       45943.000000
#                  Monday       42947.000000
#                  Saturday     26769.500000
#                  Sunday       19553.000000
#                  Thursday     46223.000000
#                  Tuesday      44819.000000
#                  Wednesday    46979.000000
# FLUSHING-MAIN    Friday       35864.000000
#                  Monday       33653.000000
#                  Saturday     25965.000000
#                  Sunday       19195.000000
#                  Thursday     34849.000000
#                  Tuesday      34600.000000
#                  Wednesday    35520.000000
# FULTON ST        Friday       34283.000000
#                  Monday       34206.000000
#                  Saturday     20030.000000
#                  Sunday       14900.000000
#                  Thursday     36436.000000
#                  Tuesday      35960.000000
#                  Wednesday    37599.000000
# GRD CNTRL-42 ST  Friday       44561.500000
#                  Monday       42873.333333
#                  Saturday     24343.611111
#                  Sunday       18731.631944
#                  Thursday     46418.000000
#                  Tuesday      45138.000000
#                  Wednesday    45829.000000
# Name: ENTRY_EXIT, dtype: float64

# %%
matrix_station_day = group_station_day.unstack()
matrix_station_day.reset_index()
matrix_station_day = matrix_station_day.reindex(columns=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
matrix_station_day = matrix_station_day.reindex(index=list(group_station.head(10).index))
matrix_station_day
# Out:
# WEEKDAY                Monday       Tuesday     Wednesday      Thursday  \
# STATION
# 34 ST-PENN STA   63903.001602  64304.000025  66247.000000  65944.000000
# 34 ST-HERALD SQ  54277.995567  56004.999931  57715.999999  55887.000000
# 125 ST           44418.669718  46464.529996  47105.220714  46910.372591
# 42 ST-PORT AUTH  44105.076804  44474.030497  46078.014148  45814.013893
# 86 ST            42947.000000  44819.000000  46979.000000  46223.000000
# GRD CNTRL-42 ST  42873.333333  45138.000000  45829.000000  46418.000000
# 14 ST-UNION SQ   39818.000000  40898.000000  44534.000000  41454.000000
# 23 ST            37074.998372  38743.937417  40521.717705  40385.011147
# FLUSHING-MAIN    33653.000000  34600.000000  35520.000000  34849.000000
# FULTON ST        34206.000000  35960.000000  37599.000000  36436.000000
#
# WEEKDAY                Friday      Saturday        Sunday
# STATION
# 34 ST-PENN STA   65294.416667  42422.562500  33385.102539
# 34 ST-HERALD SQ  55324.638889  39598.843750  31155.716309
# 125 ST           48069.541287  35352.666667  28188.611979
# 42 ST-PORT AUTH  46356.164545  33792.341146  24899.040487
# 86 ST            45943.000000  26769.500000  19553.000000
# GRD CNTRL-42 ST  44561.500000  24343.611111  18731.631944
# 14 ST-UNION SQ   44337.000000  30561.000000  21390.000000
# 23 ST            39505.750115  23391.437500  17730.897461
# FLUSHING-MAIN    35864.000000  25965.000000  19195.000000
# FULTON ST        34283.000000  20030.000000  14900.000000

# %%
matrix_station_day.applymap(lambda x:str(round(x/1000,1))+'k')
# Out:
# WEEKDAY         Monday Tuesday Wednesday Thursday Friday Saturday Sunday
# STATION
# 34 ST-PENN STA   63.9k   64.3k     66.2k    65.9k  65.3k    42.4k  33.4k
# 34 ST-HERALD SQ  54.3k   56.0k     57.7k    55.9k  55.3k    39.6k  31.2k
# 125 ST           44.4k   46.5k     47.1k    46.9k  48.1k    35.4k  28.2k
# 42 ST-PORT AUTH  44.1k   44.5k     46.1k    45.8k  46.4k    33.8k  24.9k
# 86 ST            42.9k   44.8k     47.0k    46.2k  45.9k    26.8k  19.6k
# GRD CNTRL-42 ST  42.9k   45.1k     45.8k    46.4k  44.6k    24.3k  18.7k
# 14 ST-UNION SQ   39.8k   40.9k     44.5k    41.5k  44.3k    30.6k  21.4k
# 23 ST            37.1k   38.7k     40.5k    40.4k  39.5k    23.4k  17.7k
# FLUSHING-MAIN    33.7k   34.6k     35.5k    34.8k  35.9k    26.0k  19.2k
# FULTON ST        34.2k   36.0k     37.6k    36.4k  34.3k    20.0k  14.9k

# %%
array = np.array(matrix_station_day.applymap(lambda x:str(round(x/1000,1))+'k'))
array
# Out:
# array([['63.9k', '64.3k', '66.2k', '65.9k', '65.3k', '42.4k', '33.4k'],
#        ['54.3k', '56.0k', '57.7k', '55.9k', '55.3k', '39.6k', '31.2k'],
#        ['44.4k', '46.5k', '47.1k', '46.9k', '48.1k', '35.4k', '28.2k'],
#        ['44.1k', '44.5k', '46.1k', '45.8k', '46.4k', '33.8k', '24.9k'],
#        ['42.9k', '44.8k', '47.0k', '46.2k', '45.9k', '26.8k', '19.6k'],
#        ['42.9k', '45.1k', '45.8k', '46.4k', '44.6k', '24.3k', '18.7k'],
#        ['39.8k', '40.9k', '44.5k', '41.5k', '44.3k', '30.6k', '21.4k'],
#        ['37.1k', '38.7k', '40.5k', '40.4k', '39.5k', '23.4k', '17.7k'],
#        ['33.7k', '34.6k', '35.5k', '34.8k', '35.9k', '26.0k', '19.2k'],
#        ['34.2k', '36.0k', '37.6k', '36.4k', '34.3k', '20.0k', '14.9k']],
#       dtype=object)

# %%
fig2 = plt.figure(figsize=[10,10])
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
ax2 = sns.heatmap(matrix_station_day,cmap='Blues',linecolor='white',linewidths=1,annot = array,fmt='')
plt.xlabel('Day of the Week',fontsize=15)
plt.ylabel('Top 10 Stations',fontsize=15)   
plt.title('Station Traffic in the Week',weight='bold',fontsize=15)
plt.savefig('heatmap1.png',transparent=True, bbox_inches='tight')
# Creating heatmap of traffic a day in the top 10 stations.
# Trends reveal that traffic is higher on weekdays compared with weekends

# %%
def timeperiod(time):
    if time >= datetime.time(0,0,0) and time < datetime.time(4,0,0):
        return "12am-4am"
    elif time >= datetime.time(4,0,0) and time < datetime.time(8,0,0):
        return "4am-8am"
    elif time >= datetime.time(8,0,0) and time < datetime.time(12,0,0):
        return "8am-12pm"
    elif time >= datetime.time(12,0,0) and time < datetime.time(16,0,0):
        return "12pm-4pm"    
    elif time >= datetime.time(16,0,0) and time < datetime.time(20,0,0):
        return "4pm-8pm"    
    else:
        return "8pm-12am"

# %%
df_10['TIME_PERIOD'] = df_10['TIME'].apply(timeperiod)
df_10
# Out:
# <ipython-input-40-a6528b6be240>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10['TIME_PERIOD'] = df_10['TIME'].apply(timeperiod)
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2925    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2926    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2927    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2928    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2929    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# ...       ...   ...       ...              ...           ...      ...
# 197616   N508  R453  00-00-05            23 ST            FM      IND
# 197617   N508  R453  00-00-05            23 ST            FM      IND
# 197618   N508  R453  00-00-05            23 ST            FM      IND
# 197619   N508  R453  00-00-05            23 ST            FM      IND
# 197620   N508  R453  00-00-05            23 ST            FM      IND
#
#              DATE      TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  \
# 2925   2020-08-22  02:00:00  REGULAR  9247170  2202347        138.0
# 2926   2020-08-22  06:00:00  REGULAR  9247192  2202357         22.0
# 2927   2020-08-22  10:00:00  REGULAR  9247304  2202437        112.0
# 2928   2020-08-22  14:00:00  REGULAR  9247494  2202541        190.0
# 2929   2020-08-22  18:00:00  REGULAR  9247726  2202659        232.0
# ...           ...       ...      ...      ...      ...          ...
# 197616 2020-08-28  04:00:00  REGULAR   694272  1777400          4.0
# 197617 2020-08-28  08:00:00  REGULAR   694276  1777613          4.0
# 197618 2020-08-28  12:00:00  REGULAR   694303  1777995         27.0
# 197619 2020-08-28  16:00:00  REGULAR   694400  1778301         97.0
# 197620 2020-08-28  20:00:00  REGULAR   694518  1778564        118.0
#
#         EXIT_DELTA  ENTRY_DELTA_1  EXIT_DELTA_1  ENTRY_EXIT   WEEKDAY  \
# 2925          99.0          138.0          99.0       237.0  Saturday
# 2926          10.0           22.0          10.0        32.0  Saturday
# 2927          80.0          112.0          80.0       192.0  Saturday
# 2928         104.0          190.0         104.0       294.0  Saturday
# 2929         118.0          232.0         118.0       350.0  Saturday
# ...            ...            ...           ...         ...       ...
# 197616         1.0            4.0           1.0         5.0    Friday
# 197617       213.0            4.0         213.0       217.0    Friday
# 197618       382.0           27.0         382.0       409.0    Friday
# 197619       306.0           97.0         306.0       403.0    Friday
# 197620       263.0          118.0         263.0       381.0    Friday
#
#        TIME_PERIOD
# 2925      12am-4am
# 2926       4am-8am
# 2927      8am-12pm
# 2928      12pm-4pm
# 2929       4pm-8pm
# ...            ...
# 197616     4am-8am
# 197617    8am-12pm
# 197618    12pm-4pm
# 197619     4pm-8pm
# 197620    8pm-12am
#
# [26221 rows x 18 columns]

# %%
matrix_list= []
for station in list(group_station.head(10).index):
    df_station = df_10[df_10['STATION']==station]
    group_day_time = df_station.groupby(['WEEKDAY','TIME_PERIOD'])['ENTRY_EXIT'].sum()
    matrix_day_time = group_day_time.unstack()
    matrix_day_time.reset_index()   
    matrix_day_time = matrix_day_time.reindex(index=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
    matrix_day_time = matrix_day_time.reindex(columns=["12am-4am","4am-8am","8am-12pm","12pm-4pm","4pm-8pm","8pm-12am"])
    matrix_list.append(matrix_day_time)

fig, axn = plt.subplots(2,5, sharex=True, sharey=True, figsize=(15,6))
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
cbar_ax = fig.add_axes([.91, .3, .03, .4])  

for i, ax in enumerate(axn.flat):
    station = matrix_list[i]
    sns.heatmap(station, ax=ax, cmap=cmap,
                cbar=i == 0,
                cbar_ax=None if i else cbar_ax,
                linecolor='white',linewidths=0.5)
    ax.set_title(list(group_station.head(10).index)[i])
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.savefig('heatmap2.png',transparent=True, bbox_inches='tight')
    # Creating heatmap of traffic based on day and time period for each of the 10 stations
    # Trend shows that traffic is heavier in the late afternoon and evening periods, even during weekdays
    # The trend reveals that the Covid pandemic could have caused many companies to adopt WFH arrangements, thus eliminating morning rush hours.
    # The trend reveals that the street teams should deploy manpower to these stations from late afternoon to late evenings.

# %%
df_10[(df_10['STATION']=='34 ST-PENN STA')&(df_10['WEEKDAY']=='Friday')&(df_10['TIME_PERIOD']=='4pm-8pm')]['ENTRY_EXIT'].mean()
# Check average traffic through a turnstile in 34 ST-PENN STATION on Friday at 4pm-8pm
# Out:
# 188.29931972789123

# %%
df_10[(df_10['STATION']=='34 ST-PENN STA')&(df_10['WEEKDAY']=='Friday')&(df_10['TIME_PERIOD']=='4pm-8pm')]['ENTRY_EXIT'].count()
# Check number of turnstiles in 34 ST-PENN STATION
# Out:
# 98

# %%
df_10['TRAFFIC_DELTA'] = df_10['ENTRY_DELTA_1'] - df_10['EXIT_DELTA_1']
df_10
# Out:
# <ipython-input-44-48c698b244b5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_10['TRAFFIC_DELTA'] = df_10['ENTRY_DELTA_1'] - df_10['EXIT_DELTA_1']
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2925    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2926    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2927    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2928    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 2929    N062A  R010  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# ...       ...   ...       ...              ...           ...      ...
# 197616   N508  R453  00-00-05            23 ST            FM      IND
# 197617   N508  R453  00-00-05            23 ST            FM      IND
# 197618   N508  R453  00-00-05            23 ST            FM      IND
# 197619   N508  R453  00-00-05            23 ST            FM      IND
# 197620   N508  R453  00-00-05            23 ST            FM      IND
#
#              DATE      TIME     DESC  ENTRIES    EXITS  ENTRY_DELTA  \
# 2925   2020-08-22  02:00:00  REGULAR  9247170  2202347        138.0
# 2926   2020-08-22  06:00:00  REGULAR  9247192  2202357         22.0
# 2927   2020-08-22  10:00:00  REGULAR  9247304  2202437        112.0
# 2928   2020-08-22  14:00:00  REGULAR  9247494  2202541        190.0
# 2929   2020-08-22  18:00:00  REGULAR  9247726  2202659        232.0
# ...           ...       ...      ...      ...      ...          ...
# 197616 2020-08-28  04:00:00  REGULAR   694272  1777400          4.0
# 197617 2020-08-28  08:00:00  REGULAR   694276  1777613          4.0
# 197618 2020-08-28  12:00:00  REGULAR   694303  1777995         27.0
# 197619 2020-08-28  16:00:00  REGULAR   694400  1778301         97.0
# 197620 2020-08-28  20:00:00  REGULAR   694518  1778564        118.0
#
#         EXIT_DELTA  ENTRY_DELTA_1  EXIT_DELTA_1  ENTRY_EXIT   WEEKDAY  \
# 2925          99.0          138.0          99.0       237.0  Saturday
# 2926          10.0           22.0          10.0        32.0  Saturday
# 2927          80.0          112.0          80.0       192.0  Saturday
# 2928         104.0          190.0         104.0       294.0  Saturday
# 2929         118.0          232.0         118.0       350.0  Saturday
# ...            ...            ...           ...         ...       ...
# 197616         1.0            4.0           1.0         5.0    Friday
# 197617       213.0            4.0         213.0       217.0    Friday
# 197618       382.0           27.0         382.0       409.0    Friday
# 197619       306.0           97.0         306.0       403.0    Friday
# 197620       263.0          118.0         263.0       381.0    Friday
#
#        TIME_PERIOD  TRAFFIC_DELTA
# 2925      12am-4am           39.0
# 2926       4am-8am           12.0
# 2927      8am-12pm           32.0
# 2928      12pm-4pm           86.0
# 2929       4pm-8pm          114.0
# ...            ...            ...
# 197616     4am-8am            3.0
# 197617    8am-12pm         -209.0
# 197618    12pm-4pm         -355.0
# 197619     4pm-8pm         -209.0
# 197620    8pm-12am         -145.0
#
# [26221 rows x 19 columns]

# %%
matrix_list= []
for station in list(group_station.head(10).index):
    df_station = df_10[df_10['STATION']==station]
    group_day_time = df_station.groupby(['WEEKDAY','TIME_PERIOD'])['TRAFFIC_DELTA'].sum()
    matrix_day_time = group_day_time.unstack()
    matrix_day_time.reset_index()   
    matrix_day_time = matrix_day_time.reindex(index=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
    matrix_day_time = matrix_day_time.reindex(columns=["12am-4am","4am-8am","8am-12pm","12pm-4pm","4pm-8pm","8pm-12am"])
    matrix_list.append(matrix_day_time)

fig, axn = plt.subplots(2,5, sharex=True, sharey=True, figsize=(15,6))
plt.suptitle('Net Entry/Exit of Commuters', weight='bold',fontsize=15)    
cbar_ax = fig.add_axes([.91, .3, .03, .4])  

for i, ax in enumerate(axn.flat):
    station = matrix_list[i]
    sns.heatmap(station, ax=ax, cmap='coolwarm',
                cbar=i == 0,
                cbar_ax=None if i else cbar_ax,
                linecolor='white',linewidths=0.5,vmin=-4000,vmax=4000)
    ax.set_title(list(group_station.head(10).index)[i])
    ax.set_xlabel('')
    ax.set_ylabel('')

plt.savefig('heatmap3.png',transparent=True, bbox_inches='tight')  

# Creating heatmap of traffic delta based on day and time period for each of the 10 stations
# Trend reveals stations which are in potential residential and commerical areas.

# %% [markdown]
# ## Conclusion
#
#  - Given limited manpower resources, WTWY should focus on sending street teams to the top 10 busiest MTA stations.
#  - If time is a constraint, WTWY should focus on weekdays in the period of late afternoons to late evenings.
#  - Morning period on weekdays can be avoided due to has less traffic (due to WFH), and commuters are busy reporting to work.
