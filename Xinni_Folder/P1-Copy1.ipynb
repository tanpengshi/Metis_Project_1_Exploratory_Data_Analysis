# %%
#Assumption 1:  find  10 locations for teams to go on each day of the week. 
#Assumption 2: the team would stay in the same place for the entire day , 
#they will not travel ard NYC subway in the day

# %%
import pandas as pd

# %%
import numpy as np
import datetime

# %%
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [200829,]
turnstiles_df = get_data(week_nums)

# %%
turnstiles_df.info() #217832 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217832 entries, 0 to 217831
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   217832 non-null  object
#  1   UNIT                                                                  217832 non-null  object
#  2   SCP                                                                   217832 non-null  object
#  3   STATION                                                               217832 non-null  object
#  4   LINENAME                                                              217832 non-null  object
#  5   DIVISION                                                              217832 non-null  object
#  6   DATE                                                                  217832 non-null  object
#  7   TIME                                                                  217832 non-null  object
#  8   DESC                                                                  217832 non-null  object
#  9   ENTRIES                                                               217832 non-null  int64
#  10  EXITS                                                                 217832 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 18.3+ MB

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7447810
# 1  REGULAR  7447812
# 2  REGULAR  7447824
# 3  REGULAR  7447852
# 4  REGULAR  7447937
#
#    EXITS
# 0                                            2532191
# 1                                            2532197
# 2                                            2532208
# 3                                            2532248
# 4                                            2532276

# %%
from datetime import datetime as dt
# Take the date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " + turnstiles_df.TIME, 
                                            format="%m/%d/%Y %H:%M:%S")

# %%
turnstiles_df['Day_Week'] = turnstiles_df["DATE_TIME"].dt.day_name()

# %%
#df["MID"]= df["STATION"] +" " + df["SCP"] +" " +df ["UNIT"]

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7447810
# 1  REGULAR  7447812
# 2  REGULAR  7447824
# 3  REGULAR  7447852
# 4  REGULAR  7447937
#
#    EXITS                                                                 \
# 0                                            2532191
# 1                                            2532197
# 2                                            2532208
# 3                                            2532248
# 4                                            2532276
#
#             DATE_TIME  Day_Week
# 0 2020-08-22 00:00:00  Saturday
# 1 2020-08-22 04:00:00  Saturday
# 2 2020-08-22 08:00:00  Saturday
# 3 2020-08-22 12:00:00  Saturday
# 4 2020-08-22 16:00:00  Saturday

# %%
turnstiles_df.sort_values(by=['STATION','UNIT','SCP','DATE','TIME'])
# Out:
#          C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 32304   H007  R248  00-00-00       1 AV        L      BMT  08/22/2020
# 32305   H007  R248  00-00-00       1 AV        L      BMT  08/22/2020
# 32306   H007  R248  00-00-00       1 AV        L      BMT  08/22/2020
# 32307   H007  R248  00-00-00       1 AV        L      BMT  08/22/2020
# 32308   H007  R248  00-00-00       1 AV        L      BMT  08/22/2020
# ...      ...   ...       ...        ...      ...      ...         ...
# 191298  R419  R326  00-05-01  ZEREGA AV        6      IRT  08/28/2020
# 191299  R419  R326  00-05-01  ZEREGA AV        6      IRT  08/28/2020
# 191300  R419  R326  00-05-01  ZEREGA AV        6      IRT  08/28/2020
# 191301  R419  R326  00-05-01  ZEREGA AV        6      IRT  08/28/2020
# 191302  R419  R326  00-05-01  ZEREGA AV        6      IRT  08/28/2020
#
#             TIME     DESC   ENTRIES  \
# 32304   00:00:00  REGULAR  15468806
# 32305   04:00:00  REGULAR  15468809
# 32306   08:00:00  REGULAR  15468815
# 32307   12:00:00  REGULAR  15468846
# 32308   16:00:00  REGULAR  15468918
# ...          ...      ...       ...
# 191298  05:00:00  REGULAR        39
# 191299  09:00:00  REGULAR        39
# 191300  13:00:00  REGULAR        39
# 191301  17:00:00  REGULAR        39
# 191302  21:00:00  REGULAR        39
#
#         EXITS                                                                 \
# 32304                                            17369211
# 32305                                            17369219
# 32306                                            17369335
# 32307                                            17369544
# 32308                                            17369816
# ...                                                   ...
# 191298                                                167
# 191299                                                167
# 191300                                                167
# 191301                                                167
# 191302                                                167
#
#                  DATE_TIME  Day_Week
# 32304  2020-08-22 00:00:00  Saturday
# 32305  2020-08-22 04:00:00  Saturday
# 32306  2020-08-22 08:00:00  Saturday
# 32307  2020-08-22 12:00:00  Saturday
# 32308  2020-08-22 16:00:00  Saturday
# ...                    ...       ...
# 191298 2020-08-28 05:00:00    Friday
# 191299 2020-08-28 09:00:00    Friday
# 191300 2020-08-28 13:00:00    Friday
# 191301 2020-08-28 17:00:00    Friday
# 191302 2020-08-28 21:00:00    Friday
#
# [217832 rows x 13 columns]

# %%
turnstiles_df["entry change"]=turnstiles_df.ENTRIES.diff()

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7447810
# 1  REGULAR  7447812
# 2  REGULAR  7447824
# 3  REGULAR  7447852
# 4  REGULAR  7447937
#
#    EXITS                                                                 \
# 0                                            2532191
# 1                                            2532197
# 2                                            2532208
# 3                                            2532248
# 4                                            2532276
#
#             DATE_TIME  Day_Week  entry change
# 0 2020-08-22 00:00:00  Saturday           NaN
# 1 2020-08-22 04:00:00  Saturday           2.0
# 2 2020-08-22 08:00:00  Saturday          12.0
# 3 2020-08-22 12:00:00  Saturday          28.0
# 4 2020-08-22 16:00:00  Saturday          85.0

# %%
turnstiles_df = turnstiles_df.rename(columns = {'EXITS                                                               ': 'EXITS'})

# %%
turnstiles_df["exit change"]=turnstiles_df.EXITS.diff()

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/22/2020  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME  Day_Week  entry change  \
# 0  REGULAR  7447810  2532191 2020-08-22 00:00:00  Saturday           NaN
# 1  REGULAR  7447812  2532197 2020-08-22 04:00:00  Saturday           2.0
# 2  REGULAR  7447824  2532208 2020-08-22 08:00:00  Saturday          12.0
# 3  REGULAR  7447852  2532248 2020-08-22 12:00:00  Saturday          28.0
# 4  REGULAR  7447937  2532276 2020-08-22 16:00:00  Saturday          85.0
#
#    exit change
# 0          NaN
# 1          6.0
# 2         11.0
# 3         40.0
# 4         28.0

# %%
turnstiles_df.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 217827  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 217828  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 217829  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 217830  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
# 217831  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/28/2020
#
#             TIME     DESC  ENTRIES  EXITS           DATE_TIME Day_Week  \
# 217827  05:00:00  REGULAR     5554    540 2020-08-28 05:00:00   Friday
# 217828  09:00:00  REGULAR     5554    540 2020-08-28 09:00:00   Friday
# 217829  13:00:00  REGULAR     5554    540 2020-08-28 13:00:00   Friday
# 217830  17:00:00  REGULAR     5554    540 2020-08-28 17:00:00   Friday
# 217831  21:00:00  REGULAR     5554    540 2020-08-28 21:00:00   Friday
#
#         entry change  exit change
# 217827           0.0          0.0
# 217828           0.0          0.0
# 217829           0.0          0.0
# 217830           0.0          0.0
# 217831           0.0          0.0

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#         UNIT       SCP          STATION           DATE_TIME  ENTRIES
# 93228   R141  00-00-00  FOREST HILLS 71 2020-08-26 05:00:00        2
# 193161  R436  00-00-00       NORWOOD AV 2020-08-25 05:00:00        2
# 0       R001  00-00-00  WHITEHALL S-FRY 2020-08-22 01:00:00        1
# 145224  R263  00-05-00         AVENUE H 2020-08-24 08:00:00        1
# 145214  R263  00-05-00         AVENUE H 2020-08-22 16:00:00        1

# %%
mask = ((turnstiles_df["C/A"] == "N333A") & 
(turnstiles_df["UNIT"] == "R141") & 
(turnstiles_df["SCP"] == "00-00-00") & 
(turnstiles_df["STATION"] == "FOREST HILLS 71") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2020, 8, 26).date()))
turnstiles_df[mask].head()
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 87780  N333A  R141  00-00-00  FOREST HILLS 71     EFMR      IND  08/26/2020
# 87781  N333A  R141  00-00-00  FOREST HILLS 71     EFMR      IND  08/26/2020
# 87782  N333A  R141  00-00-00  FOREST HILLS 71     EFMR      IND  08/26/2020
# 87783  N333A  R141  00-00-00  FOREST HILLS 71     EFMR      IND  08/26/2020
# 87784  N333A  R141  00-00-00  FOREST HILLS 71     EFMR      IND  08/26/2020
#
#            TIME        DESC  ENTRIES    EXITS           DATE_TIME   Day_Week  \
# 87780  01:00:00     REGULAR  1443526  2955419 2020-08-26 01:00:00  Wednesday
# 87781  05:00:00     REGULAR  1443526  2955420 2020-08-26 05:00:00  Wednesday
# 87782  05:00:00  RECOVR AUD        8        2 2020-08-26 05:00:00  Wednesday
# 87783  09:00:00     REGULAR  1443535  2955448 2020-08-26 09:00:00  Wednesday
# 87784  10:00:00  RECOVR AUD        8       82 2020-08-26 10:00:00  Wednesday
#
#        entry change  exit change
# 87780          13.0         12.0
# 87781           0.0          1.0
# 87782    -1443518.0   -2955418.0
# 87783     1443527.0    2955446.0
# 87784    -1443527.0   -2955366.0

# %%
turnstiles_df.DESC.value_counts()
#to find the no. of Regular  and Recovr AUD (1107 is abt 0.5% of the data set so drop off?)
#looking at the recover AUD  they seems like adjustment made to the entries and exit count 
#so could be added to the entries and exit count to that timing ? 
#but then we no need to add back as the entries and exit count would have adjust itself properly in later time
# we should take note of
# Out:
# REGULAR       216725
# RECOVR AUD      1107
# Name: DESC, dtype: int64

# %%
AUDmask = ((turnstiles_df["DESC"] == "RECOVR AUD") & (turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2020, 8, 22).date()))
turnstiles_df[AUDmask].head(10)
# Out:
#         C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2933   A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2975   A021  R032  01-00-01   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3017   A021  R032  01-00-02   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3059   A021  R032  01-00-03   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3101   A021  R032  01-00-04   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3143   A021  R032  01-00-05   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3185   A021  R032  01-00-06   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 3227   A021  R032  01-00-07   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 30171  G001  R151  00-00-01  CONEY IS-STILLW          DFNQ      BMT
# 31747  H001  R175  00-06-02             8 AV          ACEL      BMT
#
#              DATE      TIME        DESC  ENTRIES     EXITS  \
# 2933   08/22/2020  04:00:00  RECOVR AUD  9748875  12161821
# 2975   08/22/2020  04:00:00  RECOVR AUD  4058846   4728409
# 3017   08/22/2020  04:00:00  RECOVR AUD  2855615   2777078
# 3059   08/22/2020  04:00:00  RECOVR AUD  2833689   1338923
# 3101   08/22/2020  04:00:00  RECOVR AUD  2536242   3745986
# 3143   08/22/2020  04:00:00  RECOVR AUD  1927699   6311228
# 3185   08/22/2020  04:00:00  RECOVR AUD  2205629   6817228
# 3227   08/22/2020  04:00:00  RECOVR AUD  3600650   6148345
# 30171  08/22/2020  05:00:00  RECOVR AUD  7650714   6604941
# 31747  08/22/2020  13:00:00  RECOVR AUD     3133     12285
#
#                 DATE_TIME  Day_Week  entry change  exit change
# 2933  2020-08-22 04:00:00  Saturday           3.0         12.0
# 2975  2020-08-22 04:00:00  Saturday           2.0          5.0
# 3017  2020-08-22 04:00:00  Saturday           2.0          0.0
# 3059  2020-08-22 04:00:00  Saturday           0.0          3.0
# 3101  2020-08-22 04:00:00  Saturday           2.0          4.0
# 3143  2020-08-22 04:00:00  Saturday           2.0          3.0
# 3185  2020-08-22 04:00:00  Saturday           2.0         12.0
# 3227  2020-08-22 04:00:00  Saturday           2.0         11.0
# 30171 2020-08-22 05:00:00  Saturday           5.0         10.0
# 31747 2020-08-22 13:00:00  Saturday           0.0         53.0

# %%
AUDmask = ((turnstiles_df["DESC"] == "RECOVR AUD") & (turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2020, 8, 28).date()))
turnstiles_df[AUDmask].head()
# Out:
#         C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 11116  A060  R001  00-00-03  WHITEHALL S-FRY      R1W      BMT  08/28/2020
# 24624  C027  R216  00-00-00  BAY RIDGE-95 ST        R      BMT  08/28/2020
# 24666  C027  R216  00-00-01  BAY RIDGE-95 ST        R      BMT  08/28/2020
# 24708  C027  R216  00-00-02  BAY RIDGE-95 ST        R      BMT  08/28/2020
# 24750  C027  R216  00-03-00  BAY RIDGE-95 ST        R      BMT  08/28/2020
#
#            TIME        DESC  ENTRIES    EXITS           DATE_TIME Day_Week  \
# 11116  05:00:00  RECOVR AUD  2989066   501574 2020-08-28 05:00:00   Friday
# 24624  00:00:00  RECOVR AUD  5283158  7268448 2020-08-28 00:00:00   Friday
# 24666  00:00:00  RECOVR AUD  1292443  1358316 2020-08-28 00:00:00   Friday
# 24708  00:00:00  RECOVR AUD  3172132  3352334 2020-08-28 00:00:00   Friday
# 24750  00:00:00  RECOVR AUD  4061281  4220337 2020-08-28 00:00:00   Friday
#
#        entry change  exit change
# 11116           0.0          0.0
# 24624           9.0         57.0
# 24666          11.0         55.0
# 24708           6.0         30.0
# 24750           5.0         25.0

# %%
# Get rid of the duplicate entry
turnstiles_df.sort_values(["UNIT", "SCP", "STATION", "DATE_TIME"], 
                          inplace=True, ascending=False)
turnstiles_df.drop_duplicates(subset=["UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#         UNIT       SCP          STATION           DATE_TIME  ENTRIES
# 0       R001  00-00-00  WHITEHALL S-FRY 2020-08-22 01:00:00        1
# 145211  R263  00-05-00         AVENUE H 2020-08-22 04:00:00        1
# 145213  R263  00-05-00         AVENUE H 2020-08-22 12:00:00        1
# 145214  R263  00-05-00         AVENUE H 2020-08-22 16:00:00        1
# 145215  R263  00-05-00         AVENUE H 2020-08-22 20:00:00        1

# %%
turnstiles_df['traffic by diff'] = turnstiles_df['entry change'] + turnstiles_df['exit change']

# %%
turnstiles_df.head()
# Out:
#           C/A  UNIT       SCP      STATION LINENAME DIVISION        DATE  \
# 125080  N702A  R572  01-03-04  96 ST-2 AVE        Q      IND  08/28/2020
# 125079  N702A  R572  01-03-04  96 ST-2 AVE        Q      IND  08/28/2020
# 125078  N702A  R572  01-03-04  96 ST-2 AVE        Q      IND  08/28/2020
# 125077  N702A  R572  01-03-04  96 ST-2 AVE        Q      IND  08/28/2020
# 125076  N702A  R572  01-03-04  96 ST-2 AVE        Q      IND  08/28/2020
#
#             TIME     DESC  ENTRIES   EXITS           DATE_TIME Day_Week  \
# 125080  21:00:00  REGULAR  1503701  494373 2020-08-28 21:00:00   Friday
# 125079  17:00:00  REGULAR  1503623  494341 2020-08-28 17:00:00   Friday
# 125078  13:00:00  REGULAR  1503514  494314 2020-08-28 13:00:00   Friday
# 125077  09:00:00  REGULAR  1503446  494287 2020-08-28 09:00:00   Friday
# 125076  05:00:00  REGULAR  1503374  494247 2020-08-28 05:00:00   Friday
#
#         entry change  exit change  traffic by diff
# 125080          78.0         32.0            110.0
# 125079         109.0         27.0            136.0
# 125078          68.0         27.0             95.0
# 125077          72.0         40.0            112.0
# 125076           0.0          6.0              6.0

# %%
turnstiles_df.groupby(['STATION','UNIT','SCP', 'DATE'])[['traffic by diff']].sum()
# Out:
#                                     traffic by diff
# STATION   UNIT SCP      DATE
# 1 AV      R248 00-00-00 08/22/2020       19753910.0
#                         08/23/2020            982.0
#                         08/24/2020           1577.0
#                         08/25/2020           1811.0
#                         08/26/2020           2020.0
# ...                                             ...
# ZEREGA AV R326 00-05-01 08/24/2020              0.0
#                         08/25/2020              2.0
#                         08/26/2020              0.0
#                         08/27/2020              0.0
#                         08/28/2020              0.0
#
# [34528 rows x 1 columns]

# %%
turnstiles_df.groupby(['STATION','UNIT','SCP','DATE'])['ENTRIES'].max()
# Out:
# STATION    UNIT  SCP       DATE
# 1 AV       R248  00-00-00  08/22/2020    15468992
#                            08/23/2020    15469129
#                            08/24/2020    15469327
#                            08/25/2020    15469642
#                            08/26/2020    15470018
#                                            ...
# ZEREGA AV  R326  00-05-01  08/24/2020          39
#                            08/25/2020          39
#                            08/26/2020          39
#                            08/27/2020          39
#                            08/28/2020          39
# Name: ENTRIES, Length: 34528, dtype: int64

# %%
#turnstiles_df.groupby(['STATION','UNIT','SCP'])['ENTRIES'].min()

# %%
#df.groupby(['STATION','MID'])['EXITS'].max()

# %%
#df.groupby(['STATION','MID'])['EXITS'].min()

# %%
#df.groupby(['STATION','MID', 'DATE'])[['total ppl']].sum().head(20)

# %%
#df.groupby(['STATION','MID'])['ENTRIES'].max() - df.groupby(['STATION','MID'])['ENTRIES'].min()

# %%
#df.groupby(['STATION','MID'])['EXITS'].max() - df.groupby(['STATION','MID'])['EXITS'].min()

# %%
#since the count on the turnstiles is culmulative 
#we can get the max value - min value of each turnsiles for each day to get the daily count
#then add daily entries + exit to get the total human traffic
DTraffic_max_min = turnstiles_df.groupby(['STATION','UNIT','SCP','DATE','Day_Week'])['ENTRIES'].max() - turnstiles_df.groupby(['STATION','UNIT', 'SCP','DATE','Day_Week'])['ENTRIES'].min() + turnstiles_df.groupby(['STATION','UNIT','SCP','DATE','Day_Week'])['EXITS'].max() - turnstiles_df.groupby(['STATION','UNIT','SCP','DATE','Day_Week'])['EXITS'].min()

# %%
DTraffic_df =DTraffic_max_min.reset_index()

# %%
DTraffic_df.columns
# Out:
# Index(['STATION', 'UNIT', 'SCP', 'DATE', 'Day_Week', 0], dtype='object')

# %%
DTraffic_df = DTraffic_df.rename(columns = {0: 'Traffic'}) #rename 0 to traffic

# %%
DTraffic_df.head()
# Out:
#   STATION  UNIT       SCP        DATE   Day_Week  Traffic
# 0    1 AV  R248  00-00-00  08/22/2020   Saturday     1041
# 1    1 AV  R248  00-00-00  08/23/2020     Sunday      804
# 2    1 AV  R248  00-00-00  08/24/2020     Monday     1414
# 3    1 AV  R248  00-00-00  08/25/2020    Tuesday     1700
# 4    1 AV  R248  00-00-00  08/26/2020  Wednesday     1851

# %%
#(turnstiles_df
# .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
# .ENTRIES.count()
# .reset_index()
# .sort_values("ENTRIES", ascending=False)).head(5)
DTraffic_df.sort_values(by = ["Traffic"], ascending=False).head(20)
# Out:
#                STATION  UNIT       SCP        DATE   Day_Week     Traffic
# 34174  WORLD TRADE CTR  R029  01-03-06  08/25/2020    Tuesday  1549702036
# 34168  WORLD TRADE CTR  R029  01-03-05  08/26/2020  Wednesday  1057535892
# 21192  FOREST HILLS 71  R141  02-00-01  08/26/2020  Wednesday    16723105
# 21087  FOREST HILLS 71  R141  00-00-00  08/26/2020  Wednesday     4399153
# 10216  63 DR-REGO PARK  R202  01-06-03  08/27/2020   Thursday     1633811
# 2163    149/GRAND CONC  R205  01-06-00  08/26/2020  Wednesday      396425
# 22799  GRD CNTRL-42 ST  R046  00-00-06  08/24/2020     Monday      390605
# 11569             8 AV  R175  00-06-02  08/22/2020   Saturday      377995
# 11558             8 AV  R175  00-06-00  08/25/2020    Tuesday       65900
# 32724  TWENTY THIRD ST  R542  00-00-03  08/28/2020     Friday       20029
# 26017   KINGSBRIDGE RD  R155  01-00-03  08/24/2020     Monday       12002
# 7340   42 ST-PORT AUTH  R011  00-00-00  08/26/2020  Wednesday        5140
# 7342   42 ST-PORT AUTH  R011  00-00-00  08/28/2020     Friday        5024
# 7339   42 ST-PORT AUTH  R011  00-00-00  08/25/2020    Tuesday        4954
# 7341   42 ST-PORT AUTH  R011  00-00-00  08/27/2020   Thursday        4951
# 7338   42 ST-PORT AUTH  R011  00-00-00  08/24/2020     Monday        4903
# 7348   42 ST-PORT AUTH  R011  00-00-01  08/27/2020   Thursday        4323
# 7349   42 ST-PORT AUTH  R011  00-00-01  08/28/2020     Friday        4251
# 7346   42 ST-PORT AUTH  R011  00-00-01  08/25/2020    Tuesday        4197
# 7347   42 ST-PORT AUTH  R011  00-00-01  08/26/2020  Wednesday        4160

# %%
#noticed after a list of of huge traffice over 10k there are traffic of turnstile at 42 ST-PORT AUTH are abt the same.
#we will use 10,000 as the cut off for outlier and replace them with NaN

# %%
#DTraffic_df.loc[:, (Dtraffic_df['Traffic']>=10000)] = np.nan
DTraffic_df['Traffic'].mask(DTraffic_df['Traffic'].between(10000,1549702037 ), inplace=True)

# %%
DTraffic_df.sort_values(by = ["Traffic"], ascending=False).head(20)
# Out:
#                STATION  UNIT       SCP        DATE   Day_Week  Traffic
# 7340   42 ST-PORT AUTH  R011  00-00-00  08/26/2020  Wednesday   5140.0
# 7342   42 ST-PORT AUTH  R011  00-00-00  08/28/2020     Friday   5024.0
# 7339   42 ST-PORT AUTH  R011  00-00-00  08/25/2020    Tuesday   4954.0
# 7341   42 ST-PORT AUTH  R011  00-00-00  08/27/2020   Thursday   4951.0
# 7338   42 ST-PORT AUTH  R011  00-00-00  08/24/2020     Monday   4903.0
# 7348   42 ST-PORT AUTH  R011  00-00-01  08/27/2020   Thursday   4323.0
# 7349   42 ST-PORT AUTH  R011  00-00-01  08/28/2020     Friday   4251.0
# 7346   42 ST-PORT AUTH  R011  00-00-01  08/25/2020    Tuesday   4197.0
# 7347   42 ST-PORT AUTH  R011  00-00-01  08/26/2020  Wednesday   4160.0
# 7345   42 ST-PORT AUTH  R011  00-00-01  08/24/2020     Monday   4144.0
# 7355   42 ST-PORT AUTH  R011  00-00-02  08/27/2020   Thursday   3425.0
# 7356   42 ST-PORT AUTH  R011  00-00-02  08/28/2020     Friday   3414.0
# 7354   42 ST-PORT AUTH  R011  00-00-02  08/26/2020  Wednesday   3407.0
# 20844    FLUSHING-MAIN  R055  00-03-00  08/28/2020     Friday   3345.0
# 7352   42 ST-PORT AUTH  R011  00-00-02  08/24/2020     Monday   3342.0
# 20842    FLUSHING-MAIN  R055  00-03-00  08/26/2020  Wednesday   3325.0
# 20841    FLUSHING-MAIN  R055  00-03-00  08/25/2020    Tuesday   3318.0
# 20843    FLUSHING-MAIN  R055  00-03-00  08/27/2020   Thursday   3304.0
# 7353   42 ST-PORT AUTH  R011  00-00-02  08/25/2020    Tuesday   3251.0
# 27824   MYRTLE-WYCKOFF  R137  00-00-00  08/25/2020    Tuesday   3057.0

# %%
# groupby station
STraffic =DTraffic_df.groupby(['STATION','Day_Week'])['Traffic'].sum()
#turnstiles_df.groupby(['STATION','UNIT','SCP', 'DATE'])[['traffic by diff']].sum()

# %%
STraffic_df = STraffic.reset_index()
STraffic_df.head()
# Out:
#   STATION  Day_Week  Traffic
# 0    1 AV    Friday  10643.0
# 1    1 AV    Monday   9817.0
# 2    1 AV  Saturday   8089.0
# 3    1 AV    Sunday   6354.0
# 4    1 AV  Thursday  10668.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sns.distplot(STraffic_df['Traffic']
             [STraffic_df['Traffic'] < 50000])
# Out:
# <AxesSubplot:xlabel='Traffic'>

# %%
sns.barplot(x = 'Day_Week',y='Traffic',data=STraffic_df,order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
# Out:
# <AxesSubplot:xlabel='Day_Week', ylabel='Traffic'>

# %%
#plot hist

#map station to geo location?
#sum all station traffic?
#world trade center stn has outlier - over 1mils - 25 & 26

# %%
sns.boxplot(data=STraffic_df);

# %%
#df1.to_csv("dailytraffic.csv")

# %%
#df.to_csv("hourlytraffic.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-185-d39263fbc3d8> in <module>
# ----> 1 data.boxplot(by = 'Day_Week');
#
# NameError: name 'data' is not defined
